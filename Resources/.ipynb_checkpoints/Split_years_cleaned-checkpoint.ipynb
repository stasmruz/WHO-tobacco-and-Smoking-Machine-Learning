# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %% [markdown]
# Split the data into 4 different csv files 2012, '14, '16, and testing('18)

# %%
CigaretteData_df = pd.read_csv('cigaretteData.csv')
CigaretteData_df.head(-1)
# Out:
#      Unnamed: 0  Year      Location  CigaretteSmokingPrevalence  \
# 0             0  2018       Albania                        43.3
# 1             1  2018       Algeria                        11.1
# 2             2  2018       Andorra                        27.7
# 3             3  2018       Austria                        27.0
# 4             4  2018       Belgium                        23.4
# ..          ...   ...           ...                         ...
# 684         684  2008         Samoa                        28.7
# 685         685  2008  Saudi Arabia                         2.1
# 686         686  2008        Serbia                        38.8
# 687         687  2008    Seychelles                        34.1
# 688         688  2008  Sierra Leone                        36.6
#
#      TobaccoSmokingPrevalence  TobaccoUsePrevalance  \
# 0                        50.5                  50.5
# 1                        14.5                  18.8
# ...

# %%
Cig_df =CigaretteData_df.drop(['Unnamed: 0', 'MostSoldUSD','MostSoldBrandCigaretteCurrency','MostSoldBrandCigarettePrice','rates'], axis=1)

# %%
Cig_df.count()
# Out:
# Year                          690
# Location                      690
# CigaretteSmokingPrevalence    690
# TobaccoSmokingPrevalence      690
# TobaccoUsePrevalance          690
# dtype: int64

# %%
train_2012to2016 = Cig_df.set_index("Year")
train_2012to2016.head()
# Out:
#      Location  CigaretteSmokingPrevalence  TobaccoSmokingPrevalence  \
# Year
# 2018  Albania                        43.3                      50.5
# 2018  Algeria                        11.1                      14.5
# 2018  Andorra                        27.7                      33.8
# 2018  Austria                        27.0                      29.1
# 2018  Belgium                        23.4                      25.0
#
#       TobaccoUsePrevalance
# Year
# 2018                  50.5
# 2018                  18.8
# 2018                  33.8
# 2018                  29.1
# 2018                  25.0

# %%
# train_2012to2016 = train_2012to2016.drop(labels = [2018], axis=0)
train_2012to2016 = train_2012to2016.drop(labels=[2018], axis=0)

# %%
train_2012to2016.count()
# Out:
# Location                      582
# CigaretteSmokingPrevalence    582
# TobaccoSmokingPrevalence      582
# TobaccoUsePrevalance          582
# dtype: int64

# %%
train_2012to2016.head(100)
# Out:
#      Location  CigaretteSmokingPrevalence  TobaccoSmokingPrevalence  \
# Year
# 2016  Albania                        43.7                      51.1
# 2016  Algeria                        11.2                      14.7
# 2016  Andorra                        27.9                      33.9
# 2016  Austria                        28.5                      30.7
# 2016  Belgium                        23.8                      25.5
# ...       ...                         ...                       ...
# 2016  Myanmar                         2.7                      38.4
# 2016  Namibia                        22.9                      33.7
# 2016    Nepal                        30.2                      34.3
# 2016  Nigeria                         3.8                       4.3
# 2016   Norway                        16.1                      20.2
#
#       TobaccoUsePrevalance
# Year
# 2016                  51.1
# 2016                  19.1
# 2016                  33.9
# ...

# %%
Train12to16 = train_2012to2016
Train12to16.to_csv('2012to2016_train.csv')

# %%
Test2018 = Cig_df.loc[Cig_df['Year'] == 2018]
Test2018.to_csv('2018_test.csv')
